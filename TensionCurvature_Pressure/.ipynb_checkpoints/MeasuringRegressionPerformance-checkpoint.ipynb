# %%
# Neural network for multi regression
from numpy import loadtxt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import ceil, pi
import random
from random import sample
from sklearn.model_selection import RepeatedKFold
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import h5py # For model saving: https://machinelearningmastery.com/save-load-keras-deep-learning-models/
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
model = load_model('best_model_regression_P.h5')

# %% [markdown]
# # Tasks:
# *Possible error metrics*
#
# Measure model performance using
# MAE
# MSE
# Average height offset
# Does it correctly yield an omega shaped bud?
# Average neck diameter gap
# Average neck inflection height offset
#
# *Results*
#
# Does error depend on distance to nearest point in parameter space?
# Does error correlate with class membership?

# %%
train = pd.read_csv('train.csv')
validation = pd.read_csv('validation.csv')


train['C0_norm'] = (train.C0*-1 - min(train.C0*-1))/(max(train.C0*-1) - min(train.C0*-1))
#test['C0_norm'] = (test.C0*-1 - min(train.C0*-1))/(max(train.C0*-1) - min(train.C0*-1))
validation['C0_norm'] = (validation.C0*-1 - min(train.C0*-1))/(max(train.C0*-1) - min(train.C0*-1))

train['lam_norm'] = (train.lam_dim - min(train.lam_dim))/(max(train.lam_dim) - min(train.lam_dim))
#test['lam_norm'] = (test.lam_dim - min(train.lam_dim))/(max(train.lam_dim) - min(train.lam_dim))
validation['lam_norm'] = (validation.lam_dim - min(train.lam_dim))/(max(train.lam_dim) - min(train.lam_dim))

train['rad_norm'] = (train.rad - min(train.rad))/(max(train.rad) - min(train.rad))
#test['rad_norm'] = (test.rad - min(train.rad))/(max(train.rad) - min(train.rad))
validation['rad_norm'] = (validation.rad - min(train.rad))/(max(train.rad) - min(train.rad))

train['pressure_norm'] = (train.pressure_dim - min(train.pressure_dim))/(max(train.pressure_dim) - min(train.pressure_dim))
#test['pressure_norm'] = (test.pressure_dim - min(train.pressure_dim))/(max(train.pressure_dim) - min(train.pressure_dim))
validation['pressure_norm'] = (validation.pressure_dim - min(train.pressure_dim))/(max(train.pressure_dim) - min(train.pressure_dim))

train['rad_norm'] = (train.rad - min(train.rad))/(max(train.rad) - min(train.rad))
validation['rad_norm'] = (validation.rad - min(train.rad))/(max(train.rad) - min(train.rad))

# %%
features = ['C0_norm', 'rad_norm', 'pressure_norm', 'lam_norm']

preds = model.predict(validation[features])

# %%
val_omegas = validation.where(validation.omega == 1).dropna(how = 'all')
for i in set(val_omegas.Param_id):
    val_sub = validation.where(validation.Param_id == i).dropna(how = 'all')
    for count in np.arange(len(val_sub) - 1,len(val_sub)): # sample(set(np.arange(0,len(val_sub))), 10):
        plt.plot(model.predict(val_sub[features])[count,0:50], model.predict(val_sub[features])[count,50:], label = 'prediction', c = 'black', alpha = .8)
        plt.plot(val_sub.iloc[count, -104:-54], val_sub.iloc[count, -54:-4], label = 'actual', c = 'blue', alpha = .8)
        
    plt.show()

# %%
errs = []
dists = []

for i in np.asarray(validation.index):
    dist = min(np.abs(train.C0_norm - validation.C0_norm[i]) + np.abs(train.lam_norm - validation.lam_norm[i]) + np.abs(train.rad_norm - validation.rad_norm[i]) + np.abs(train.pressure_norm - validation.pressure_norm[i])) # This is just the L1 or Manhattan/Minkowski metric. 
    dists.append(dist)
    # As the dimension of parameter space increases, using norms like the Manhattan norm is more effective at differentiating distance between
    # points: https://towardsdatascience.com/the-surprising-behaviour-of-distance-metrics-in-high-dimensions-c2cb72779ea6
    err = mean_absolute_error(preds[i], validation.iloc[i,-104:-4])
    errs.append(err)

# %%
errs_df = pd.DataFrame({'Errors': errs, "Distances": dists})

# %%
plt.scatter(dists, errs, alpha = .3)
plt.xlabel('Distance (normalized)')
plt.ylabel('Mean Absolute Error (nm)')

reg = LinearRegression().fit(np.array(dists).reshape(-1, 1), np.array(errs).reshape(-1, 1))
score = reg.score(np.array(dists).reshape(-1, 1), np.array(errs).reshape(-1, 1))
reg_preds = reg.predict(np.array(dists).reshape(-1, 1))
plt.plot(np.array(dists).reshape(-1, 1), reg_preds, c = 'black', alpha = .5)
print("Coefficient of determination (r2): " + str(round(score, 3)))
# Out:
# Coefficient of determination (r2): 0.022

# %%
sns.distplot(dists, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(dists), 1/len(dists))}, label = 'True positive')

plt.xlabel('Distance to nearest training point (normalized)')
plt.ylabel('Normalized count')
plt.ylim(0,1)
# Out:
# /opt/anaconda3/envs/muscleLengthPrediction_env/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 1.0)

# %%
sns.distplot(errs, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(errs), 1/len(errs))}, label = 'True positive')

plt.xlabel('Error (MAE)')
plt.ylabel('Normalized count')
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# Plot the highest error predictions
high_err_inds = errs_df.where(errs_df.Errors > 70).dropna(how = 'all').index
val_sub = validation.iloc[list(high_err_inds)]
for i in np.arange(0,len(val_sub)):
    plt.plot(preds[i, -100:-50], preds[i, -50:], label = 'Prediction')
    plt.plot(val_sub.iloc[i, -104:-54], val_sub.iloc[i, -54:-4], label = 'Data')
    plt.legend()
    plt.gca().set_aspect('equal', adjustable='box')
    plt.draw()
    plt.show()

# %%
high_err_inds = errs_df.where(errs_df.Errors > 70).dropna(how = 'all').index
val_sub = validation.iloc[list(high_err_inds)]

for i in sample(set(val_sub.Param_id), 3):
    val_sub = validation.where(validation.Param_id == i).dropna(how = 'all')
    for j in sample(set(val_sub.index),30):
        plt.plot(preds[j, -100:-50], preds[j, -50:], c = 'orange', alpha = .4, label = 'Prediction')
        plt.plot(val_sub.loc[j][-104:-54], val_sub.loc[j][-54:-4], c = 'black', alpha = .4, label = 'Data')
        plt.gca().set_aspect('equal', adjustable='box')
        plt.draw()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e9cdd1d3f2ed> in <module>
#       4 for i in sample(set(val_sub.Param_id), 3):
#       5     val_sub = validation.where(validation.Param_id == i).dropna(how = 'all')
# ----> 6     for j in sample(set(val_sub.index),30):
#       7         plt.plot(preds[j, -100:-50], preds[j, -50:], c = 'orange', alpha = .4, label = 'Prediction')
#       8         plt.plot(val_sub.loc[j][-104:-54], val_sub.loc[j][-54:-4], c = 'black', alpha = .4, label = 'Data')
#
# /opt/anaconda3/envs/muscleLengthPrediction_env/lib/python3.6/random.py in sample(self, population, k)
#     318         n = len(population)
#     319         if not 0 <= k <= n:
# --> 320             raise ValueError("Sample larger than population or is negative")
#     321         result = [None] * k
# ...

# %%
validation['Errors'] = errs_df.Errors
validation['Distances'] = errs_df.Distances

# %%
# Calculate errors based on x and y locations being divided by their maximums to provide some normalization for size.
# We'll scale only by validation maxes so that the predictions don't get an artificial reduction in error from being rescaled to max out at one. 

norm_errs = []
low_ran = -107
up_ran = -7

#validation = validation.where(validation['y0'] > 20).dropna(how = 'all') # Only consider where the bilayer is somewhat deformed 
for i in np.arange(0,len(validation)): 
    xs = validation.iloc[i, low_ran : low_ran + 50]
    ys = validation.iloc[i, low_ran + 50 : up_ran]
    
    if xs.max() > 10 and ys.max() > 10:
        x_data_norm = xs/(xs.max())
        y_data_norm = ys/(ys.max())

        x_preds_norm = preds[validation.index[i], 0:50]/xs.max() # (preds[validation.index[i], 0:50].max())
        y_preds_norm = preds[validation.index[i], 50:100]/ys.max() # (preds[validation.index[i], 50:100].max())

        inner_errs = []
        for j in np.arange(0,50):
            xer = np.abs(x_data_norm - x_preds_norm[j]).min()
            yer = np.abs(y_data_norm - y_preds_norm[j]).min()
            inner_errs.append(xer)
            inner_errs.append(yer)
        
        norm_errs.append(np.sum(inner_errs)/(50*2))
            
        ###er = (mean_absolute_error(x_data_norm, x_preds_norm) + mean_absolute_error(y_data_norm, y_preds_norm))/2
        ###norm_errs.append(er)
                
    else: 
        norm_errs.append(np.nan)
        
validation['norm_Errors'] = norm_errs

# %%
#plt.scatter(np.arange(0,len(validation['norm_Errors'])), validation['norm_Errors'])
validation['norm_Errors']
# Out:
# 0       0.0095
# 1       0.0095
# 2       0.0095
# 3       0.0095
# 4       0.0095
#          ...
# 3736    0.0095
# 3737    0.0095
# 3738    0.0095
# 3739    0.0095
# 3740    0.0095
# Name: norm_Errors, Length: 3741, dtype: float64

# %%
val_sub_omega = validation.where(validation.omega == 1).dropna(how = 'all')
val_sub_hill = validation.where(validation.omega == 0).dropna(how = 'all')

# %%
val_sub_omega.Errors.max()
temp = val_sub_omega.where(val_sub_omega.Errors > 70).dropna(how = 'all')

low_ran = -107
up_ran = -7

for i in np.arange(0,len(temp)):
    plt.plot(temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black', label = 'Actual')
    plt.plot(-1*temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black')
    plt.plot(preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange')
    plt.plot(-1*preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange', label = 'Prediction')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.legend()
    plt.draw()
    plt.show()

# %%
val_sub_hill.Errors.max()
temp = val_sub_hill.where(val_sub_hill.Errors > 60).dropna(how = 'all')

for i in np.arange(0,len(temp)):
    plt.plot(temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black', label = 'Actual')
    plt.plot(-1*temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black')
    plt.plot(preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange')
    plt.plot(-1*preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange', label = 'Prediction')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.legend()
    plt.draw()
    plt.show()

# %%
val_sub_hill.norm_Errors.max()
temp = val_sub_hill.where(val_sub_hill.norm_Errors > .03).dropna(how = 'all')

for i in np.arange(0,len(temp)):
    plt.plot(temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black', label = 'Actual')
    plt.plot(-1*temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black')
    plt.plot(preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange')
    plt.plot(-1*preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange', label = 'Prediction')
    #plt.gca().set_aspect('equal', adjustable='box')
    plt.legend()
    #plt.draw()
    plt.show()

# %%
val_sub_omega.norm_Errors.max()
temp = val_sub_omega.where(val_sub_omega.norm_Errors > .007).dropna(how = 'all')

for i in np.arange(0,len(temp)):
    print(temp.index[i])
    plt.scatter(temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black', label = 'Actual')
    #plt.plot(-1*temp.iloc[i,low_ran:low_ran + 50],temp.iloc[i,low_ran + 50:up_ran], c = 'black')
    plt.scatter(preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange')
    #plt.plot(-1*preds[temp.index[i], 0:50], preds[temp.index[i], 50:100], c = 'orange', label = 'Prediction')
    plt.title('Error: ' + str(round(temp.norm_Errors.iloc[i], 3)))
    plt.gca().set_aspect('equal', adjustable='box')
    plt.legend()
    plt.draw()
    plt.show()
# Out:
# 31
# 84
# 88
# 89
# 91
# 92
# 94
# 96
# 97
# 99
# 165
# 166
# 326
# 329
# 945
# 946
# 947
# 948
# 949
# 950
# 951
# 952
# 953
# 954
# 955
# 956
# 957
# 958
# 1427
# 1429
# 1430
# 1431
# 1432
# 1434
# 1435
# 1604
# 1607
# 1608
# 1918
# 1919
# 2218
# 2860
# 2861
# 2862
# 2949
# 2954
# 2955
# 2956
# 2957
# 2958
# 2960
# 2963
# 3326
# 3327

# %%
errs = val_sub_hill.norm_Errors.dropna(how = 'all')
sns.distplot(errs, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(errs), 1/len(errs))}, label = 'Hill type')
sns.distplot(val_sub_omega.norm_Errors, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(val_sub_omega.norm_Errors), 1/len(val_sub_omega.norm_Errors))}, label = 'Omega type')

plt.xlabel('Error (normalized)')
plt.ylabel('Normalized count')
plt.title('Normalized error distribution')
plt.ylim(0,1)
plt.legend()
plt.show()



errs = val_sub_hill.Errors.dropna(how = 'all')
sns.distplot(errs, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(errs), 1/len(errs))}, label = 'Hill type')
sns.distplot(val_sub_omega.Errors, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(val_sub_omega.norm_Errors), 1/len(val_sub_omega.norm_Errors))}, label = 'Omega type')

plt.xlabel('Error (MAE)')
plt.ylabel('Normalized count')
plt.ylim(0,1)
plt.title('Error distribution')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/envs/muscleLengthPrediction_env/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
errs = val_sub_hill.Distances.dropna(how = 'all')
sns.distplot(errs, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(errs), 1/len(errs))}, label = 'Hill type')
plt.xlabel('Error (MAE)')
plt.ylabel('Normalized count')
#plt.ylim(0,1)

sns.distplot(val_sub_omega.Distances, bins = 10, kde=False,
             hist_kws={'weights': np.full(len(val_sub_omega.norm_Errors), 1/len(val_sub_omega.norm_Errors))}, label = 'Omega type')

plt.xlabel('Distance to nearest train point (normalized)')
plt.ylabel('Normalized count')
plt.title('Distances distribution')
plt.ylim(0,1)
plt.legend()
plt.show()
